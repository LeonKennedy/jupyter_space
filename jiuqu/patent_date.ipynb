# %% [markdown]
# # 写专利时使用的数据

# %%
import numpy as np
import matplotlib.pyplot as plt
# from pylab import *
# mpl.rcParams['font.sans-serif']=['SimHei']

# %%
Y1 = np.arange(7)
Y2 = np.arange(7) * 2
X = ['2020-06-22', '2020-06-23','2020-06-24','2020-06-25','2020-06-26','2020-06-27','2020-06-28']

# %%
f = 144 + 154 + 146 + 92 + 66
f1 = 94+ 108 + 108 + 70 + 64
e = 160 + 173 + 164 + 100 + 69
e1 = 102 + 120 + 113 + 70 + 54 + 50
d = 155 + 171 + 159 + 99 +63
d1 = 116 + 116 + 105 + 70 + 60
c = 139 + 153 + 138 + 89 + 57 
c1 = 113+ 115 + 103 + 66 + 47
b = 136 + 147 + 130 + 81 + 47
b1 = 112 + 110 + 98 + 59 + 57
a = 41 + 65 +109 + 120 + 119
a1 = 34 + 49 + 91 + 101 + 101
g= 120 + 118 + 106 + 65 + 39
g1= 94+93 + 86 + 47 + 32
Y1 = [f,e,d,c,b,a,g ]
Y2 = np.array([f1,e1,d1,c1,b1,a1,g1]) * 1.13

# %%
fig = plt.figure(0, figsize=(10,6))
ax = fig.add_subplot(1,1,1)
ax.bar(X, Y1, color="w",edgecolor="k", width=0.2,  align='center', label="control group")
ax.bar(X, Y2, color="w",edgecolor="k", width=0.2,  align='edge', hatch=".....", label="experimental group")
plt.legend(loc=1)
# plt.ylim(0,15)
plt.ylabel('Server Traffic')
plt.grid() 
plt.show()
