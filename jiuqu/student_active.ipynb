# %%
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append("/Users/coffee/Documents/code/QkidsAutomation")
from teacher_predict.DataFarm import DataFarm, aggreate

# %% [markdown]
# # 活跃用户

# %%
df = pd.read_pickle('/Users/coffee/Documents/code/QkidsAutomation/teacher_predict/student_active_data/active_student.pkl')
df.plot(figsize=(26,8))

# %%
df.plot(figsize=(26,8))

# %%
a = aggreate()
b = a.teacher_count
b.index = [d.date() for d in b.index]
c = b.groupby(level=0).sum()
c.plot(figsize=(26,8))

# %%
c
# Out:
# 2018-01-01    1177.0
# 2018-01-02    1397.0
# 2018-01-03    1164.0
# 2018-01-04    1070.0
# 2018-01-05    1074.0
#                ...
# 2020-05-20    8385.0
# 2020-05-21    8257.0
# 2020-05-22    8143.0
# 2020-05-23    9028.0
# 2020-05-24    8881.0
# Name: teacher_count, Length: 869, dtype: float64
