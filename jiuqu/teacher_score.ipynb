# %%
from odps import ODPS, options
from odps.df import agg
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from odps.df import DataFrame
options.sql.use_odps2_extension = True
odps = ODPS('LTAItDVDpC9aEMXJ', 'U6iEFCZCzoPUbjou1FW45SQruxIfFt', 'Qkids_V2')

# %%
df = DataFrame(odps.get_table("dwd_teacher_wide"))

# %%
teachers = df[df.status_id == 2].to_pandas()
# Out:
# TransientProgressBar(value=0.0)
# InstancesProgress()
# HTMLNotifier()

# %% [markdown]
# #### 老师人数

# %%
len(teachers)
# Out:
# 7932

# %%
teachers.head(10)
# Out:
#     id  user_name  status_id  resume_status  recruitment_status  train_status  \
# 0    1      Peter          2              2                   2             1
# 1   23   Teacher3          2              2                   2             2
# 2   30    Michael          2              2                   2             2
# 3   70    Tiffany          2              2                   2             2
# 4   81     Bob003          2              2                   2             2
# 5   96  Kelsey012          2              2                   2             2
# 6  149   Teacher6          2              2                   2             2
# 7  165  George068          2              2                   2             2
# 8  197  Tifani097          2              2                   2             2
# 9  224  Cidney120          2              2                   2             2
#
#    schedule_status  account_status  schedule_fixed  trainer_id  ...  absent  \
# ...

# %% [markdown]
# #### 老师评分分布情况

# %%
teachers[["teacher_rating"]].describe()
# Out:
#        teacher_rating
# count     7500.000000
# mean         4.776274
# std          0.070894
# min          3.325563
# 25%          4.753697
# 50%          4.788164
# 75%          4.813496
# max          5.000000
