# %%
import matplotlib.pyplot as plt
import numpy as np
from student_appointment import StudentAppointment

# %%
sa = StudentAppointment()

# %%
data = sa.getScater('2018-18')
#X = np.array([i[0] for i in data ])
X = np.array(list(range(len(data))))
y = np.array(data)
plt.figure(figsize=(14,12),dpi=80)
plt.plot(X,y,label="2018-18",linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-17')),label="2018-17",linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-16')),label="2018-16", linewidth = 0.5)
#plt.plot(X,np.array(sa.getScater('2018-15')),label="2018-15", linewidth = 0.5)
#Eplt.plot(X,np.array(sa.getScater('2018-14')),label="2018-14", linewidth = 0.5)
#plt.plot(X,np.array(sa.getScater('2018-13')),label="2018-13", linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-04')),label="2018-04", linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-03')),label="2018-03", linewidth = 0.5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,12),dpi=80)
plt.plot(X,y,label="2018-18",linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-06')),label="2018-06", linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-05')),label="2018-05", linewidth = 0.5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,12),dpi=80)
plt.plot(X,y,label="2018-18",linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-08')),label="2018-08", linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-07')),label="2018-07", linewidth = 0.5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,12),dpi=80)
plt.plot(X,y,label="2018-18",linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-10')),label="2018-10", linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-09')),label="2018-09", linewidth = 0.5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,12),dpi=80)
plt.plot(X,y,label="2018-18",linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-12')),label="2018-12", linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-11')),label="2018-11", linewidth = 0.5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,12),dpi=80)
plt.plot(X,y,label="2018-18",linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-14')),label="2018-14", linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-13')),label="2018-13", linewidth = 0.5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,12),dpi=80)
plt.plot(X,y,label="2018-18",linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-16')),label="2018-16", linewidth = 0.5)
plt.plot(X,np.array(sa.getScater('2018-15')),label="2018-15", linewidth = 0.5)
plt.legend()
plt.show()
